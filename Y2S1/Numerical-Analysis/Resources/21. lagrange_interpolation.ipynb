# %%
def lagrange_interpolation(x_points, y_points, x):

    if len(x_points) != len(y_points):
        raise ValueError("x_points and y_points must have the same length.")

    n = len(x_points)
    result = 0.0

    for i in range(n):
        # Compute L_i(x)
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term

    return result


# Example usage:
x_points = [0, 1, 2]
y_points = [1, 3, 2]
x = 1.5

y = lagrange_interpolation(x_points, y_points, x)
print(f"Interpolated value at x={x} is y={y}")
# Out:
# Interpolated value at x=1.5 is y=2.875
